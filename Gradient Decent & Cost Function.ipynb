# %%
import numpy as np

# %%
def gradient_descent(x,y):
  m_curr = b_curr = 0          # initial values of m and b
  iteration= 100
  n = len(x)
  learning_rate = 0.001
  for i in range(iteration):
    y_predicted = m_curr * x * b_curr
    cost = (1/n) * sum ([val**2 for val in (y-y_predicted)])
    md = -(2/n) * sum(x* (y-y_predicted))
    bd= -(2/n) * sum(y-y_predicted)
    m_curr = m_curr - learning_rate *md
    b_curr = b_curr - learning_rate *bd
    print("m {}, b {}, cost {} , iteration {} ".format(m_curr , b_curr, cost , i))

x = np.array([1,2,3,4,5])
y = np.array([5,7,8,11,13])

gradient_descent(x,y)
# Out:
# m 0.06080000000000001, b 0.0176, cost 85.60000000000001 , iteration 0
# m 0.12157645824000002, b 0.035193579520000004, cost 85.53495173178328 , iteration 1
# m 0.18228232660348176, b 0.05276790725549503, cost 85.34005576737216 , iteration 2
# m 0.24287071615158212, b 0.07031019531406786, cost 85.01620336437179 , iteration 3
# m 0.30329503782683104, b 0.08780773758913575, cost 84.5649693162263 , iteration 4
# m 0.36350914150277214, b 0.10524794768257424, cost 83.98859730674968 , iteration 5
# m 0.42346745249841766, b 0.12261839613593212, cost 83.28997857842154 , iteration 6
# m 0.48312510470191294, b 0.13990684673688536, cost 82.47262423711823 , iteration 7
# m 0.5424380694823909, b 0.15710129167701573, cost 81.54063161477784 , iteration 8
# m 0.6013632796122406, b 0.1741899853487929, cost 80.49864520106674 , iteration 9
# m 0.6598587474732115, b 0.19116147658360316, cost 79.35181273349733 , iteration 10
# m 0.7178836768781326, b 0.20800463914858164, cost 78.10573710104723 , iteration 11
# m 0.7753985679046194, b 0.22470870033762347, cost 76.7664247679238 , iteration 12
# m 0.8323653142069943, b 0.24126326751099847, cost 75.34023146088983 , iteration 13
# m 0.8887472923466896, b 0.2576583524581881, cost 73.83380588511525 , iteration 14
# m 0.9445094427585397, b 0.27388439347960175, cost 72.25403223985892 , iteration 15
# m 0.9996183420494947, b 0.28993227510440767, cost 70.60797229683241 , iteration 16
# m 1.0540422664062716, b 0.30579334538352865, cost 68.90280778164025 , iteration 17
# m 1.1077512459682315, b 0.3214594307186086, cost 67.14578376334119 , iteration 18
# m 1.1607171101002824, b 0.33692284820916796, cost 65.3441537103381 , iteration 19
# m 1.2129135235768802, b 0.35217641552096735, cost 63.505126814089934 , iteration 20
# m 1.2643160137613356, b 0.36721345829854607, cost 61.63581811734153 , iteration 21
# m 1.3149019889338338, b 0.3820278151637729, cost 59.74320191255941 , iteration 22
# m 1.3646507479861223, b 0.39661384035985153, cost 57.834068800969206 , iteration 23
# m 1.4135434817601304, b 0.41096640411639923, cost 55.91498672490996 , iteration 24
# m 1.4615632663613856, b 0.42508089082583245, cost 53.99226620797564 , iteration 25
# m 1.508695048825595, b 0.4389531951342532, cost 52.07192996030801 , iteration 26
# m 1.5549256255579602, b 0.45257971606126185, cost 50.15968693197948 , iteration 27
# m 1.6002436139995093, b 0.46595734927259347, cost 48.26091082700873 , iteration 28
# m 1.644639418002978, b 0.47908347763717585, cost 46.38062302532735 , iteration 29
# m 1.688105187422585, b 0.49195596020615956, cost 44.523479800873616 , iteration 30
# m 1.7306347724376205, b 0.5045731197557147, cost 42.693763671616665 , iteration 31
# m 1.772223673139316, b 0.5169337290379953, cost 40.89537867217005 , iteration 32
# m 1.812868984914319, b 0.5290369958857234, cost 39.131849301981696 , iteration 33
# m 1.8525693401566226, b 0.5408825473154426, cost 37.40632287193419 , iteration 34
# m 1.8913248468334096, b 0.5524704127727482, cost 35.721574949420294 , iteration 35
# m 1.9291370244194266, b 0.5638010066598438, cost 34.08001758628381 , iteration 36
# m 1.9660087376996727, b 0.5748751102817291, cost 32.48371000501544 , iteration 37
# m 2.001944128921874, b 0.5856938533423295, cost 30.934371415742266 , iteration 38
# m 2.0369485487588994, b 0.5962586951160637, cost 29.433395639243834 , iteration 39
# m 2.0710284865174655, b 0.6065714054138545, cost 27.981867218812255 , iteration 40
# m 2.104191500003647, b 0.6166340454555403, cost 26.580578715560222 , iteration 41
# m 2.136446145428318, b 0.6264489487531779, cost 25.230048897073814 , iteration 42
# m 2.1678019077071484, b 0.6360187021019498, cost 23.930541547420876 , iteration 43
# m 2.1982691314805596, b 0.6453461267674256, cost 22.682084646798174 , iteration 44
# m 2.2278589531495054, b 0.6544342599498654, cost 21.48448969090945 , iteration 45
# m 2.2565832341934096, b 0.6632863365982029, cost 20.33737094293633 , iteration 46
# m 2.284454496007394, b 0.6719057716383805, cost 19.24016443417425 , iteration 47
# m 2.3114858564673164, b 0.6802961426729048, cost 18.192146552596796 , iteration 48
# m 2.337690968403367, b 0.6884611732009187, cost 17.19245208138527 , iteration 49
# m 2.3630839601362275, b 0.6964047164007897, cost 16.240091571479663 , iteration 50
# m 2.387679378204249, b 0.7041307395102502, cost 15.333967953199235 , iteration 51
# m 2.4114921323859058, b 0.7116433088325201, cost 14.472892311727461 , iteration 52
# m 2.4345374430989826, b 0.718946575390632, cost 13.655598769596532 , iteration 53
# m 2.4568307912367042, b 0.7260447612463743, cost 12.880758436128794 , iteration 54
# m 2.478387870481288, b 0.7329421464948971, cost 12.146992399028704 , iteration 55
# m 2.499224542117264, b 0.7396430569410722, cost 11.452883746942513 , iteration 56
# m 2.519356792350361, b 0.7461518524591897, cost 10.796988623819123 , iteration 57
# m 2.538800692122768, b 0.7524729160334825, cost 10.177846326350197 , iteration 58
# m 2.5575723594021205, b 0.7586106434733059, cost 9.59398846469782 , iteration 59
# m 2.5756879239096175, b 0.7645694337935324, cost 9.043947214211155 , iteration 60
# m 2.593163494242144, b 0.7703536802478579, cost 8.52626269197939 , iteration 61
# m 2.61001512733412, b 0.7759677620002149, cost 8.039489496967532 , iteration 62
# m 2.6262588001969482, b 0.7814160364173499, cost 7.582202456240643 , iteration 63
# m 2.6419103838673146, b 0.7867028319638134, cost 7.1530016225107325 , iteration 64
# m 2.6569856194900883, b 0.7918324416791153, cost 6.750516570048629 , iteration 65
# m 2.671500096457171, b 0.7968091172155924, cost 6.373410036999656 , iteration 66
# m 2.6854692325201843, b 0.801637063414596, cost 6.020380962431151 , iteration 67
# m 2.6989082557923343, b 0.8063204333979096, cost 5.690166966122458 , iteration 68
# m 2.7118321885530774, b 0.8108633241508396, cost 5.381546318277551 , iteration 69
# m 2.7242558327681907, b 0.8152697725731433, cost 5.093339445084512 , iteration 70
# m 2.736193757237527, b 0.8195437519738714, cost 4.824410014445018 , iteration 71
# m 2.7476602862829806, b 0.8236891689862679, cost 4.573665644323436 , iteration 72
# m 2.7586694898899506, b 0.8277098608790778, cost 4.340058274084584 , iteration 73
# m 2.769235175216811, b 0.8316095932409489, cost 4.1225842369598045 , iteration 74
# m 2.779370879388498, b 0.8353920580150453, cost 3.9202840694535968 , iteration 75
# m 2.7890898634922703, b 0.8390608718615287, cost 3.732242091122215 , iteration 76
# m 2.7984051076959067, b 0.8426195748261568, cost 3.557585785758724 , iteration 77
# m 2.8073293074110692, b 0.8460716292939283, cost 3.3954850126387637 , iteration 78
# m 2.81587487042718, b 0.8494204192074131, cost 3.2451510741436027 , iteration 79
# m 2.824053914943955, b 0.8526692495301699, cost 3.10583566380416 , iteration 80
# m 2.831878268433619, b 0.8558213459364419, cost 2.976829716618571 , iteration 81
# m 2.8393594672668008, b 0.8588798547091278, cost 2.8574621813999315 , iteration 82
# m 2.8465087570391128, b 0.8618478428288492, cost 2.7470987329200747 , iteration 83
# m 2.8533370935384657, b 0.8647282982377636, cost 2.6451404397363003 , iteration 84
# m 2.8598551442961933, b 0.8675241302625984, cost 2.551022401825276 , iteration 85
# m 2.866073290668077, b 0.8702381701822031, cost 2.464212370503786 , iteration 86
# m 2.872001630394337, b 0.8728731719257287, cost 2.384209361589938 , iteration 87
# m 2.8776499805905775, b 0.8754318128883396, cost 2.3105422713492625 , iteration 88
# m 2.8830278811245145, b 0.8779166948521405, cost 2.242768503475427 , iteration 89
# m 2.88814459833612, b 0.8803303450007601, cost 2.1804726141712756 , iteration 90
# m 2.893009129061483, b 0.8826752170167682, cost 2.1232649813181976 , iteration 91
# m 2.8976302049233147, b 0.8849536922518132, cost 2.070780502745517 , iteration 92
# m 2.902016296853515, b 0.8871680809600496, cost 2.022677327731067 , iteration 93
# m 2.90617561981564, b 0.8893206235860837, cost 1.9786356250740789 , iteration 94
# m 2.910116137697407, b 0.891413492099293, cost 1.9383563903756518 , iteration 95
# m 2.9138455683455815, b 0.8934487913669769, cost 1.901560294535031 , iteration 96
# m 2.9173713887176773, b 0.8954285605593666, cost 1.8679865749155546 , iteration 97
# m 2.920700840126913, b 0.8973547745800673, cost 1.837391970146885 , iteration 98
# m 2.9238409335587394, b 0.8992293455160199, cost 1.8095496991045037 , iteration 99

# %% [markdown]
# ####Cost function is reducing in every iteration
