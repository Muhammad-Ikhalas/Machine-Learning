# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('/content/Buy_ensurence_csv.csv')
df.head()
# Out:
#    age  bought_insurence
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
plt.scatter(df.age,df.bought_insurence , marker='+',color='red')

# %%
df.shape
# Out:
# (28, 2)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test=train_test_split(df[['age']],df.bought_insurence,test_size=0.1)

# %%
X_test
# Out:
#    age
# 9   61
# 5   56
# 4   46

# %%
from sklearn.linear_model import LogisticRegression

# %%
model= LogisticRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
model.predict(X_test)
# Out:
# array([1, 1, 1])

# %%
model.score(X_test,y_test)
# Out:
# 1.0
